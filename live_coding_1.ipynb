# %%
import pandas as pd
import numpy as np

# %%
gallup = pd.read_csv('data/USAIPO1936-0053.csv')

# %%
gallup.head()
# Out:
#    form     state               region female              age    class  \
# 0   NaN   Indiana         East Central   Male              NaN      Av+
# 1   NaN  Illinois         East Central   Male              NaN      Av+
# 2   NaN  Michigan         East Central   Male              NaN       Av
# 3   NaN  Virginia  South and Southwest   Male  55 yrs and over  P or P+
# 4   NaN   Florida  South and Southwest   Male  55 yrs and over      Av+
#
#        OCCUPATION1  OCCUPATION2  OCCUPATION3 black  ... StPOAbrv    SOUTH11  \
# 0  Skilled workers          NaN          NaN   NaN  ...       in  Non-South
# 1  Skilled workers          NaN          NaN   NaN  ...       il  Non-South
# 2         Business          NaN          NaN   NaN  ...       mi  Non-South
# 3  Skilled workers          NaN          NaN   NaN  ...       va      South
# 4  Skilled workers          NaN          NaN   NaN  ...       fl      South
#
#    SOUTH11xBLACK    SOUTH12 SOUTH12xBLACK      south SOUTHxBLACK  year  \
# ...
